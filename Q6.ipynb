# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample data
data = pd.DataFrame({
    'Category': ['A', 'B', 'C', 'D', 'E'],
    'Values': [23, 45, 56, 78, 12]
})

# Set aesthetic style and color palette
sns.set_theme(style="whitegrid", palette="pastel")

# Create a bar plot with controlled aesthetics
plt.figure(figsize=(8, 6))
sns.barplot(x="Category", y="Values", data=data)

# Adding titles and labels for clarity
plt.title("Values by Category", fontsize=14)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Values", fontsize=12)

plt.show()

# %%
Seaborn is a powerful Python visualization library based on Matplotlib, with several advantages for creating visually appealing and informative statistical graphics. Here are some key advantages of Seaborn and the role of controlling figure aesthetics:

Advantages of Seaborn
Built-in Themes and Color Palettes: Seaborn provides a range of built-in themes and color palettes that enhance the visual appeal of charts.
Statistical Plot Types: It offers several statistical plots, such as box plots, violin plots, and pair plots, that simplify data analysis and exploration.
Simplified Syntax: Seaborn functions are easier to use than Matplotlib for creating complex plots, making it ideal for quick and exploratory data analysis.
Integration with Pandas: Seaborn works seamlessly with Pandas DataFrames, making it easy to plot data directly without extensive reshaping.
Automatic Aesthetic Control: Seaborn automatically adjusts the aesthetics to ensure plots are easy to read, allowing for quick customization with minimal code.
Role of Controlling Figure Aesthetics
In Seaborn, controlling figure aesthetics allows you to change the look and feel of your plots, making it easier to create visualizations that align with specific data presentation goals. Adjusting aspects like theme, color palette, and style helps to focus the viewer's attention on key insights.
